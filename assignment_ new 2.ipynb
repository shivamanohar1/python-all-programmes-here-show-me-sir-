# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamanohar1/1st-program-indexing-in-python/blob/main/assignment_%20new%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %%
bank = [ [ [ ["C101", "Rahul", "Savings", 85000], ["C102", "Anita", "Current", 150000], ["C103", "Kiran", "Loan", 500000] ], [ ["C104", "Sneha", "Savings", 95000], ["C105", "Vikram", "Current", 275000], ["C106", "Meena", "Loan", 750000] ] ],

[
    [
        ["C201", "Arjun", "Savings", 120000],
        ["C202", "Pooja", "Current", 325000],
        ["C203", "Ramesh", "Loan", 900000]
    ],
    [
        ["C204", "Priya", "Savings", 45000],
        ["C205", "Amit", "Current", 185000],
        ["C206", "Divya", "Loan", 650000]
    ]
],

[
    [
        ["C301", "Nikhil", "Savings", 78000],
        ["C302", "Kavya", "Current", 240000],
        ["C303", "Suresh", "Loan", 1000000]
    ],
    [
        ["C304", "Neha", "Savings", 135000],
        ["C305", "Rohan", "Current", 410000],
        ["C306", "Asha", "Loan", 550000]
    ]
]
]

# %% [markdown]
# 1.Print Rahul's complete record.

# %%
bank[0][0][0]
# Out:
# ['C101', 'Rahul', 'Savings', 85000]

# %% [markdown]
# 2.Print Anita's account type.

# %%
bank[0][0][1][-2]
# Out:
# 'Current'

# %% [markdown]
# 3.Print Kiran's loan amount.

# %%
bank[0][0][2][-1]
# Out:
# 500000

# %% [markdown]
# 4.Print Sneha's customer ID.

# %%
bank[0][1][0][-4]
# Out:
# 'C104'

# %% [markdown]
# 5.Print Vikram's balance.

# %%
bank[0][1][1][-1]
# Out:
# 275000

# %% [markdown]
# 6.Print Meena's complete record.

# %%
bank[0][1][2]
# Out:
# ['C106', 'Meena', 'Loan', 750000]

# %% [markdown]
# 7.Print Arjun's customer ID.

# %%
bank[1][0][0][0]
# Out:
# 'C201'

# %% [markdown]
# 8.Print Pooja's name.

# %%
bank[1][0][1][1]
# Out:
# 'Pooja'

# %% [markdown]
# 9.Print Ramesh's account type.

# %%
bank[1][0][2][2]
# Out:
# 'Loan'

# %% [markdown]
# 10.Print Priya's balance.

# %%
bank[1][1][0][-1]
# Out:
# 45000

# %% [markdown]
# 11.Print Amit's account type.

# %%
bank[1][1][1][2]
# Out:
# 'Current'

# %% [markdown]
# 12.Print Divya's customer ID.

# %%
bank[1][1][2][0]
# Out:
# 'C206'

# %% [markdown]
# 13.Print Nikhil's account type.

# %%
bank[2][0][0][2]
# Out:
# 'Savings'

# %% [markdown]
# 14.Print Kavya's balance.

# %%
bank[2][0][1][3]
# Out:
# 240000

# %% [markdown]
# 15.Print Suresh's loan amount.

# %%
bank[2][0][2][3]
# Out:
# 1000000

# %% [markdown]
# 16.Print Neha's name.

# %%
bank[2][1][0][1]
# Out:
# 'Neha'

# %% [markdown]
# 17.Print Rohan's complete record.

# %%
bank[2][1][1]
# Out:
# ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# 18.Print Asha's account type.

# %%
bank[2][1][2][2]
# Out:
# 'Loan'

# %% [markdown]
# 19.Print all customers in Bank 1, Branch 1.

# %%
bank[0][0]
# Out:
# [['C101', 'Rahul', 'Savings', 85000],
#  ['C102', 'Anita', 'Current', 150000],
#  ['C103', 'Kiran', 'Loan', 500000]]

# %% [markdown]
# 20.Print all customers in Bank 1, Branch 2.

# %%
bank[0][1]
# Out:
# [['C104', 'Sneha', 'Savings', 95000],
#  ['C105', 'Vikram', 'Current', 275000],
#  ['C106', 'Meena', 'Loan', 750000]]

# %% [markdown]
# 21.Print all customers in Bank 2, Branch 1.

# %%
bank[1][0]
# Out:
# [['C201', 'Arjun', 'Savings', 120000],
#  ['C202', 'Pooja', 'Current', 325000],
#  ['C203', 'Ramesh', 'Loan', 900000]]

# %% [markdown]
# 22.Print all customers in Bank 2, Branch 2.

# %%
bank[1][1]
# Out:
# [['C204', 'Priya', 'Savings', 45000],
#  ['C205', 'Amit', 'Current', 185000],
#  ['C206', 'Divya', 'Loan', 650000]]

# %% [markdown]
# 23.Print all customers in Bank 3, Branch 1.

# %%
bank[2][0]
# Out:
# [['C301', 'Nikhil', 'Savings', 78000],
#  ['C302', 'Kavya', 'Current', 240000],
#  ['C303', 'Suresh', 'Loan', 1000000]]

# %% [markdown]
# 24.Print all customers in Bank 3, Branch 2.

# %%
bank[2][1]
# Out:
# [['C304', 'Neha', 'Savings', 135000],
#  ['C305', 'Rohan', 'Current', 410000],
#  ['C306', 'Asha', 'Loan', 550000]]

# %% [markdown]
# 25.Print all branches of Bank 1.

# %%
bank[0]
# Out:
# [[['C101', 'Rahul', 'Savings', 85000],
#   ['C102', 'Anita', 'Current', 150000],
#   ['C103', 'Kiran', 'Loan', 500000]],
#  [['C104', 'Sneha', 'Savings', 95000],
#   ['C105', 'Vikram', 'Current', 275000],
#   ['C106', 'Meena', 'Loan', 750000]]]

# %% [markdown]
# 26.Print all branches of Bank 2.

# %%
bank[1]
# Out:
# [[['C201', 'Arjun', 'Savings', 120000],
#   ['C202', 'Pooja', 'Current', 325000],
#   ['C203', 'Ramesh', 'Loan', 900000]],
#  [['C204', 'Priya', 'Savings', 45000],
#   ['C205', 'Amit', 'Current', 185000],
#   ['C206', 'Divya', 'Loan', 650000]]]

# %% [markdown]
# 27.Print all branches of Bank 3.

# %%
bank[2]
# Out:
# [[['C301', 'Nikhil', 'Savings', 78000],
#   ['C302', 'Kavya', 'Current', 240000],
#   ['C303', 'Suresh', 'Loan', 1000000]],
#  [['C304', 'Neha', 'Savings', 135000],
#   ['C305', 'Rohan', 'Current', 410000],
#   ['C306', 'Asha', 'Loan', 550000]]]

# %% [markdown]
# 28.Print the first customer from every bank's first branch.

# %%
print(bank[0][0][0])
print(bank[1][0][0])
print(bank[2][0][0])
# Out:
# ['C101', 'Rahul', 'Savings', 85000]
# ['C201', 'Arjun', 'Savings', 120000]
# ['C301', 'Nikhil', 'Savings', 78000]

# %% [markdown]
# 29.Print the second customer from every bank's second branch.

# %%
print(bank[0][1][1])
print(bank[1][1][1])
print(bank[2][1][1])
# Out:
# ['C105', 'Vikram', 'Current', 275000]
# ['C205', 'Amit', 'Current', 185000]
# ['C305', 'Rohan', 'Current', 410000]

# %% [markdown]
# 30.Print the loan amount of the last customer in Bank 3, Branch 2.

# %%
print(bank[2][1][2][3])
# Out:
# 550000

# %% [markdown]
# 1.Create a list of 5 employee names and add a new employee using append().

# %%
x=["salman","ravi","rahul","teja","hari"]
x.append("basha")
print(x)
# Out:
# ['salman', 'ravi', 'rahul', 'teja', 'hari', 'basha']

# %% [markdown]
# 2.Create a list of account numbers and add three new account numbers using extend().

# %%
x=["1224","02928","9877"]
x.extend(["726256"])
x
# Out:
# ['1224', '02928', '9877', '726256']

# %% [markdown]
# 3.Insert a new customer at the beginning of a customer list using insert()

# %%
x=["jbn","gsys","ysgs","pqr"]
x.insert(0,"bhsb")
x
# Out:
# ['bhsb', 'jbn', 'gsys', 'ysgs', 'pqr']

# %% [markdown]
# 4.Insert a transaction amount at index 3 in a list.

# %%
x=[123,544,344]
x.insert(3,876)
x
# Out:
# [123, 544, 344, 876]

# %% [markdown]
# 5.Remove the last item from a list using pop().

# %%
x=["mango","banana","apple","orange"]
x.pop(3)
x
# Out:
# ['mango', 'banana', 'apple']

# %% [markdown]
# 6.Remove the customer "Rahul" from a customer list using remove().

# %%
x=["ravi","raghav","rahul","varun"]
x.remove("rahul")
x
# Out:
# ['ravi', 'raghav', 'varun']

# %% [markdown]
# 7.Count how many times the account type "Savings" appears in a list using count().

# %%
x=["ravi","Savings",1234,"Savings"]
x.count("Savings")
# Out:
# 2

# %% [markdown]
# 8.Find the index of "Current" in a list of account types using index().

# %%
x = ["Savings", "Current", "Fixed Deposit", "Salary"]

x.index("Current")
# Out:
# 1

# %% [markdown]
# 9.Reverse a list of transaction IDs using reverse().

# %%
Transactions_ID=[123,4546,789,9876,654]
Transactions_ID.reverse()
Transactions_ID
# Out:
# [654, 9876, 789, 4546, 123]

# %% [markdown]
# 10.Sort a list of account balances in ascending order using sort().

# %%
z=[4,6,1,3,2,6,4,7,8,2]
z.sort()
z
# Out:
# [1, 2, 2, 3, 4, 4, 6, 6, 7, 8]

# %% [markdown]
# 11.Sort a list of customer names in descending order using sort().

# %%
z=[4,6,1,3,2,6,4,7,8,2]
z.sort(reverse=True)
z
# Out:
# [8, 7, 6, 6, 4, 4, 3, 2, 2, 1]

# %% [markdown]
# 12.Make a copy of a list using copy() and verify that modifying the copied list does not affect the original list.

# %%
z = ["Savings", "Current", "Fixed Deposit"]
m = z.copy()
m.append("Salary")

print("Original list:", z)
print("Copied list:", m)
# Out:
# Original list: ['Savings', 'Current', 'Fixed Deposit']
# Copied list: ['Savings', 'Current', 'Fixed Deposit', 'Salary']

# %% [markdown]
# 13.Clear all elements from a list using clear().

# %%
z = ["Savings", "Current", "Fixed Deposit"]
z.clear()
z
# Out:
# []

# %% [markdown]
# 14.Append a nested list containing a new customer's details to an existing customer list.
# > Add blockquote

# %%
x = [
    ["salman", 101, "Savings"],
    ["Basha", 102, "Current"]
]

y = ["Charlie", 103, "Fixed Deposit"]

x.append(y)

print(x)
# Out:
# [['salman', 101, 'Savings'], ['Basha', 102, 'Current'], ['Charlie', 103, 'Fixed Deposit']]

# %% [markdown]
# 15.Extend a list of branch names with another list of new branches.

# %%
branchess = ["Hyderabad", "chennai", "Mumbai"]

new_branches = ["Banglore", "kerala"]

branchess.extend(new_branches)

print(branchess)
# Out:
# ['Hyderabad', 'chennai', 'Mumbai', 'Banglore', 'kerala']

# %% [markdown]
# 16.Remove the first occurrence of the balance 50000 from a list using remove().

# %%
balances = [25000, 50000, 75000, 50000, 100000]

balances.remove(50000)

print(balances)
# Out:
# [25000, 75000, 50000, 100000]

# %% [markdown]
# 17.Pop the element at index 2 from a list and print the removed value.

# %%
accounts = ["Savings", "Current", "Fixed Deposit", "Salary"]

removed = accounts.pop(2)

print(removed)
print( accounts)
# Out:
# Fixed Deposit
# ['Savings', 'Current', 'Salary']

# %% [markdown]
# #18.Count how many times the city "Bangalore" appears in a list.ion

# %%
Cities = ["Bangalore", "Mumbai", "Bangalore", "Delhi", "Bangalore"]

count = Cities.count("Bangalore")

count
# Out:
# 3

# %% [markdown]
# 19.Reverse a list of bank names and print the result.

# %%
banks = ["SBI", "BankofBaroda", "Canara", "Axis"]

banks.reverse()

banks
# Out:
# ['Axis', 'Canara', 'BankofBaroda', 'SBI']

# %% [markdown]
# 20.Create a list of loan amounts and sort it in descending order

# %%
loan_amounts = [250000, 500000, 150000, 750000, 300000]

loan_amounts.sort(reverse=True)

loan_amounts
# Out:
# [750000, 500000, 300000, 250000, 150000]
