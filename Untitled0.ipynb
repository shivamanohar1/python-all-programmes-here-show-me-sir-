# %% [markdown]
# <a href="https://colab.research.google.com/github/shivamanohar1/1st-program-indexing-in-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="edukron data science and data engineering batch 2026"
print(text)
# Out:
# edukron data science and data engineering batch 2026

# %%
print(text[0:7])
print(text[-52:-45])
# Out:
# edukron
# edukron

# %%
print(text[8:13])
print(text[-44:-40])
# Out:
# data
# data

# %%
print(text[13:20])
print(text[-39:-32])
# Out:
# science
# science

# %%
print(text[21:25])
print(text[-31:-28])
# Out:
# and
# and

# %%
print(text[25:42])
print(text[-27:-11])
# Out:
# data engineering
# data engineering

# %%
print(text[30:42])
print(text[-22:-11])
# Out:
# engineering
# engineering

# %%
print(text[42:48])
print(text[-10:-5])
# Out:
# batch
# batch

# %%
print(text[48:52])
print(text[-4:])
# Out:
# 2026
# 2026

# %%
print(text[13:30])
print(text[-39:-23])
# Out:
# science and data
# science and data

# %%
print(text[8:48])
print(text[-44:-5])
# Out:
# data science and data engineering batch
# data science and data engineering batch
